# %% [markdown]
# ## <div align="center"> TUGAS LAB IS388 Data Analysis </div>
# ## <div align="center"> WEEK [08]: [Topic]</div>
# #### <div align="center"> Semester Ganjil 2024/2025 </div>
# ---

# %%
import datetime
import uuid

studentName = "Muhammad Irfan Prasetyo Ardana"
studentNIM = "00000127901"
studentClass = "IS388-AL"

# %%
myDate = datetime.datetime.now()
myDevice = str(uuid.uuid1())

print("Name: \t\t{}".format(studentName))
print("NIM: \t\t{}".format(studentNIM))
print("Class: \t\t{}".format(studentClass))
print("Start: \t\t{}".format(myDate))
print("Device ID: \t{}".format(myDevice))
# Out:
# Name: 		Muhammad Irfan Prasetyo Ardana
# NIM: 		00000127901
# NIM: 		IS388-AL
# Start: 		2025-10-07 11:13:19.282655
# Device ID: 	f4b7c196-a333-11f0-8a38-3aa704bc3405

# %% [markdown]
# ---

# %% [markdown]
# ## <div align="center"> Guided Lab </div>

# %% [markdown]
# ### Enter Guided Lab Code Here:

# %% [markdown]
# ----

# %% [markdown]
# ## <div align="center"> Conclusion </div>

# %% [markdown]
# ### Enter Your Conclusion Here:

# %% [markdown]
# ----

# %%
studentName2 = "Muhammad Irfan Prasetyo Ardana"
studentNIM2 = "00000127901"
studentClass2 = "IS388-AL"

# %%
print("Name: \t\t{}".format(studentName2))
print("NIM: \t\t{}".format(studentNIM2))
print("Class: \t\t{}".format(studentClass2))
print("End: \t\t{}".format(myDate))
print("Device ID: \t{}".format(myDevice))
# Out:
# Name: 		Muhammad Irfan Prasetyo Ardana
# NIM: 		00000127901
# NIM: 		IS388-AL
# End: 		2025-10-07 11:13:19.282655
# Device ID: 	f4b7c196-a333-11f0-8a38-3aa704bc3405

# %% [markdown]
# ----

# %% [markdown]
# ## <div align="center"> Reference </div>

# %% [markdown]
# ### Input Your Reference Here  (Jika ada):

# %% [markdown]
# ----
